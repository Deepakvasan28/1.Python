# %%
i=int(input('value:'))
if (i==10):
    print('correct')
else:
    print('incorrect')
# Out:
# value: 10
# correct

# %%
d=(input('Enter the Password:'))
if (d=='HOPE@123'):
    print('Your password is correct')
else:
    print('incorrect')
# Out:
# Enter the Password: HOPE@123
# Your password is correct

# %%
age=(int(input('age:')))
if(age==20):
    print('Adult')
# Out:
# age: 20
# Adult

# %%
d=(int(input('Enter any number:')))
if(d==1):
       print('No is positive')
# Out:
# Enter any number: 1
# No is positive

# %%
dv=(int(input('Enter a number to check:')))
if(dv%2!=0):
        print('yes divisible')
else:
        print('No is not divisible by 5')
# Out:
# Enter a number to check: 22
# No is not divisible by 5
